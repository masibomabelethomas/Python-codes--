# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
import pandas as pd
data = pd.read_csv("D:\DATA\SALARY.csv")
data
# Out:
#          NAME    SALARY Direction depart     TAX  TRANSPORT  tatal tax  \
# 0        wetu   50000.0     north   chem   10000       5000   299880.0
# 1      MASIBO  234000.0     north   chem    3422      12000        NaN
# 2       EDWIN  124000.0     south   chem   24458      12234        NaN
# 3       LAURA  134000.0     south    bio   14000      11234        NaN
# 4     MSHINDI  200000.0     north    eng   50000       5666        NaN
# 5  MZEE MZIMA       NaN   central    bio    3000      42552        NaN
# 6    WANYONYI  450000.0      east    eng   45000      45000        NaN
# 7    KAIGWARA  345000.0      east   wter   50000      45646        NaN
# 8       DORIS  500000.0   central    phy  100000      12345        NaN
# 9         TOM   10000.0      west    mat   20000     132424        NaN
#
#   TOTAL SALARY  TRANS used sumif.42000  SUMIFS  Unnamed: 10  Unnamed: 11
# 0      2037000                133198.0    10.0  32410.10000          2.0
# ...

# %%
#removing Nan values in  Salary column
data2 = data1.apply (pd.to_numeric, errors='coerce')
data2 = data1.dropna()
data2
# Out:
#        NAME    SALARY Direction depart     TAX  TRANSPORT
# 0      wetu   50000.0     north   chem   10000       5000
# 1    MASIBO  234000.0     north   chem    3422      12000
# 2     EDWIN  124000.0     south   chem   24458      12234
# 3     LAURA  134000.0     south    bio   14000      11234
# 4   MSHINDI  200000.0     north    eng   50000       5666
# 6  WANYONYI  450000.0      east    eng   45000      45000
# 7  KAIGWARA  345000.0      east   wter   50000      45646
# 8     DORIS  500000.0   central    phy  100000      12345
# 9       TOM   10000.0      west    mat   20000     132424

# %%
#dropping columns in data that wont be used
data1=data.drop(['tatal tax','TOTAL SALARY','TRANS used sumif.42000','SUMIFS','Unnamed: 10','Unnamed: 11'],axis=1)
data1
# Out:
#          NAME    SALARY Direction depart     TAX  TRANSPORT
# 0        wetu   50000.0     north   chem   10000       5000
# 1      MASIBO  234000.0     north   chem    3422      12000
# 2       EDWIN  124000.0     south   chem   24458      12234
# 3       LAURA  134000.0     south    bio   14000      11234
# 4     MSHINDI  200000.0     north    eng   50000       5666
# 5  MZEE MZIMA       NaN   central    bio    3000      42552
# 6    WANYONYI  450000.0      east    eng   45000      45000
# 7    KAIGWARA  345000.0      east   wter   50000      45646
# 8       DORIS  500000.0   central    phy  100000      12345
# 9         TOM   10000.0      west    mat   20000     132424

# %%
# FINDING CORRELATION BETWEEN SALARY AND TAX  PAID

print( data2[['SALARY','TAX']].corr())

#
# Out:
#           SALARY       TAX
# SALARY  1.000000  0.772707
# TAX     0.772707  1.000000

# %%
#correlation between the salary ,Tax and Transport

corr = data2.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data2.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data2.columns)
ax.set_yticklabels(data2.columns)
plt.show()

# %%
#when there is no correlation between 2 variables (when correlation is 0 or near 0) the color is gray.
#The darkest red means there is a perfect positive correlation,
#while the darkest blue means there is a perfect negative correlation.
